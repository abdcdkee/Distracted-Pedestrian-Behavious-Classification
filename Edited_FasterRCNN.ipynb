# %%
# %tensorflow_version 1.x
# !pip install keras==2.0.3
import pandas
import numpy
import os
import matplotlib
import cv2
import sklearn
import h5py
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# TensorFlow 1.x selected.
# Collecting keras==2.0.3
#   Downloading https://files.pythonhosted.org/packages/1b/36/fc4b247ec139ad9cc6f223ed10729d85401fc5203703c23457794f9bfe60/Keras-2.0.3.tar.gz (196kB)
#      |████████████████████████████████| 204kB 2.7MB/s
# Requirement already satisfied: theano in /usr/local/lib/python3.6/dist-packages (from keras==2.0.3) (1.0.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.0.3) (3.13)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from keras==2.0.3) (1.12.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from theano->keras==2.0.3) (1.18.5)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from theano->keras==2.0.3) (1.4.1)
# Building wheels for collected packages: keras
#   Building wheel for keras (setup.py) ... done
#   Created wheel for keras: filename=Keras-2.0.3-cp36-none-any.whl size=232962 sha256=0e0a0ebb7fd6dad0296fe04b16ac8c5365f25c68d0d00e439c0c91dea4bea6db
#   Stored in directory: /root/.cache/pip/wheels/a6/fb/de/faea9e49d563a35f198c6dede7f9260074b5beb8f9bffaaaa1
# Successfully built keras
# ERROR: textgenrnn 1.4.1 has requirement keras>=2.1.5, but you'll have keras 2.0.3 which is incompatible.
# Installing collected packages: keras
#   Found existing installation: Keras 2.3.1
#     Uninstalling Keras-2.3.1:
#       Successfully uninstalled Keras-2.3.1
# Successfully installed keras-2.0.3
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
# !unzip -uq "/content/drive/My Drive/originalV2.zip" -d "/content/"

# %%
# %cd /content/original/
# !python train_frcnn.py -o simple -p annotate.txt
# Out:
# /content/original
# Using TensorFlow backend.
# Parsing annotation files
# Training images per class:
# {'Pedastrian': 256, 'bg': 0}
# Num classes (including bg) = 2
# Config has been written to config.pickle, and can be loaded when testing to ensure correct results
# Num train samples 88
# Num val samples 12
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:47: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:351: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3176: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3043: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3153: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /content/original/keras_frcnn/RoiPoolingConv.py:105: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3045: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1064: calling reduce_prod_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# loading weights from resnet50_weights_tf_dim_ordering_tf_kernels.h5
# Could not load pretrained model weights. Weights can be found in the keras application folder 		https://github.com/fchollet/keras/tree/master/keras/applications
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:675: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2642: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1046: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# Starting training
# Epoch 1/50
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:768: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:521: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:764: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:141: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:146: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:151: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-07-12 08:50:18.603687: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-07-12 08:50:18.604032: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x27dd100 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-07-12 08:50:18.604066: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-07-12 08:50:18.609826: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-07-12 08:50:18.786578: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-12 08:50:18.787640: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x27dcf40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-07-12 08:50:18.787672: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-07-12 08:50:18.789044: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-12 08:50:18.789880: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-07-12 08:50:18.790334: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-07-12 08:50:19.052915: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-07-12 08:50:19.158866: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-07-12 08:50:19.203954: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-07-12 08:50:19.472302: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-07-12 08:50:19.501079: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-07-12 08:50:19.993781: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-07-12 08:50:19.994106: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-12 08:50:19.995115: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-12 08:50:19.995947: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-07-12 08:50:19.999773: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-07-12 08:50:20.001744: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-07-12 08:50:20.001778: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-07-12 08:50:20.001797: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-07-12 08:50:20.003072: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-12 08:50:20.004033: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-12 08:50:20.004871: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-07-12 08:50:20.004924: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:300: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:308: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 2020-07-12 08:50:30.082977: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-07-12 08:50:34.464845: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 50/50 [==============================] - 74s - rpn_cls: 1.0706 - rpn_regr: 0.1773 - detector_cls: 0.4913 - detector_regr: 0.4572
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 4.96
# Classifier accuracy for bounding boxes from RPN: 0.810625
# Loss RPN classifier: 1.0706232984306008
# Loss RPN regression: 0.17725625865161418
# Loss Detector classifier: 0.49132567912340164
# Loss Detector regression: 0.4571885269880295
# Elapsed time: 74.82334089279175
# Total loss decreased from inf to 2.196393763193646, saving weights
# Epoch 2/50
# Average number of overlapping bounding boxes from RPN = 4.96 for 50 previous iterations
# 50/50 [==============================] - 33s - rpn_cls: 0.3714 - rpn_regr: 0.1297 - detector_cls: 0.4234 - detector_regr: 0.4127
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 4.52
# Classifier accuracy for bounding boxes from RPN: 0.85875
# Loss RPN classifier: 0.37140676958355473
# Loss RPN regression: 0.12972755499184133
# Loss Detector classifier: 0.4234120124578476
# Loss Detector regression: 0.41274241924285887
# Elapsed time: 55.20064973831177
# Total loss decreased from 2.196393763193646 to 1.3372887562761024, saving weights
# Epoch 3/50
# Average number of overlapping bounding boxes from RPN = 4.52 for 50 previous iterations
# 50/50 [==============================] - 25s - rpn_cls: 0.3399 - rpn_regr: 0.1411 - detector_cls: 0.4416 - detector_regr: 0.4390
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 4.9
# Classifier accuracy for bounding boxes from RPN: 0.846875
# Loss RPN classifier: 0.3399063494942402
# Loss RPN regression: 0.1411020653694868
# Loss Detector classifier: 0.4416405963897705
# Loss Detector regression: 0.43899046927690505
# Elapsed time: 25.95056962966919
# Epoch 4/50
# Average number of overlapping bounding boxes from RPN = 4.9 for 50 previous iterations
# 50/50 [==============================] - 24s - rpn_cls: 0.2880 - rpn_regr: 0.1457 - detector_cls: 0.4399 - detector_regr: 0.4224
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 4.96
# Classifier accuracy for bounding boxes from RPN: 0.845
# Loss RPN classifier: 0.28800960540305826
# Loss RPN regression: 0.14572083927690982
# Loss Detector classifier: 0.4398587462306023
# Loss Detector regression: 0.4224148142337799
# Elapsed time: 24.49077534675598
# Total loss decreased from 1.3372887562761024 to 1.2960040051443502, saving weights
# Epoch 5/50
# Average number of overlapping bounding boxes from RPN = 4.96 for 50 previous iterations
# 50/50 [==============================] - 26s - rpn_cls: 0.1978 - rpn_regr: 0.1538 - detector_cls: 0.4429 - detector_regr: 0.4022
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.12
# Classifier accuracy for bounding boxes from RPN: 0.84
# Loss RPN classifier: 0.19777800036594273
# Loss RPN regression: 0.1538312095031142
# Loss Detector classifier: 0.4428682452440262
# Loss Detector regression: 0.4021691138297319
# Elapsed time: 27.004018306732178
# Total loss decreased from 1.2960040051443502 to 1.196646568942815, saving weights
# Epoch 6/50
# Average number of overlapping bounding boxes from RPN = 5.12 for 50 previous iterations
# 50/50 [==============================] - 27s - rpn_cls: 0.2187 - rpn_regr: 0.1294 - detector_cls: 0.4634 - detector_regr: 0.3999
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.6
# Classifier accuracy for bounding boxes from RPN: 0.825
# Loss RPN classifier: 0.21874055026099085
# Loss RPN regression: 0.129392414316535
# Loss Detector classifier: 0.4633929002285004
# Loss Detector regression: 0.39988039135932923
# Elapsed time: 27.724788665771484
# Epoch 7/50
# Average number of overlapping bounding boxes from RPN = 5.6 for 50 previous iterations
# 50/50 [==============================] - 25s - rpn_cls: 0.1788 - rpn_regr: 0.1374 - detector_cls: 0.4076 - detector_regr: 0.4184
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 4.4
# Classifier accuracy for bounding boxes from RPN: 0.8625
# Loss RPN classifier: 0.17875794823659816
# Loss RPN regression: 0.13735072497278453
# Loss Detector classifier: 0.40763895601034167
# Loss Detector regression: 0.4184025908261538
# Elapsed time: 25.021820306777954
# Total loss decreased from 1.196646568942815 to 1.1421502200458782, saving weights
# Epoch 8/50
# Average number of overlapping bounding boxes from RPN = 4.4 for 50 previous iterations
# 50/50 [==============================] - 25s - rpn_cls: 0.2178 - rpn_regr: 0.1202 - detector_cls: 0.4120 - detector_regr: 0.3946
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 4.88
# Classifier accuracy for bounding boxes from RPN: 0.8475
# Loss RPN classifier: 0.21780870079062878
# Loss RPN regression: 0.12017150174826384
# Loss Detector classifier: 0.4119671702384949
# Loss Detector regression: 0.3945700169354677
# Elapsed time: 26.17302441596985
# Epoch 9/50
# Average number of overlapping bounding boxes from RPN = 4.88 for 50 previous iterations
# 50/50 [==============================] - 26s - rpn_cls: 0.2290 - rpn_regr: 0.1308 - detector_cls: 0.4250 - detector_regr: 0.4111
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 4.98
# Classifier accuracy for bounding boxes from RPN: 0.844375
# Loss RPN classifier: 0.229032944298815
# Loss RPN regression: 0.13081033330410718
# Loss Detector classifier: 0.4249796435236931
# Loss Detector regression: 0.4111105248332024
# Elapsed time: 26.396536350250244
# Epoch 10/50
# Average number of overlapping bounding boxes from RPN = 4.98 for 50 previous iterations
# 50/50 [==============================] - 26s - rpn_cls: 0.1310 - rpn_regr: 0.1353 - detector_cls: 0.4261 - detector_regr: 0.3750
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 4.88
# Classifier accuracy for bounding boxes from RPN: 0.8475
# Loss RPN classifier: 0.1309852682912606
# Loss RPN regression: 0.13533914719708265
# Loss Detector classifier: 0.426124287545681
# Loss Detector regression: 0.374980299025774
# Elapsed time: 26.32521414756775
# Total loss decreased from 1.1421502200458782 to 1.0674290020597983, saving weights
# Epoch 11/50
# Average number of overlapping bounding boxes from RPN = 4.88 for 50 previous iterations
# 50/50 [==============================] - 25s - rpn_cls: 0.1506 - rpn_regr: 0.1299 - detector_cls: 0.4343 - detector_regr: 0.4036
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.3
# Classifier accuracy for bounding boxes from RPN: 0.834375
# Loss RPN classifier: 0.15060203433269634
# Loss RPN regression: 0.12989700198173523
# Loss Detector classifier: 0.4343186596035957
# Loss Detector regression: 0.4036016708239913
# Elapsed time: 26.132025718688965
# Epoch 12/50
# Average number of overlapping bounding boxes from RPN = 5.3 for 50 previous iterations
# 50/50 [==============================] - 26s - rpn_cls: 0.0949 - rpn_regr: 0.1095 - detector_cls: 0.4370 - detector_regr: 0.4001
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.02
# Classifier accuracy for bounding boxes from RPN: 0.843125
# Loss RPN classifier: 0.09487369015143486
# Loss RPN regression: 0.10945192846935242
# Loss Detector classifier: 0.43695502817630766
# Loss Detector regression: 0.40013273373246194
# Elapsed time: 26.032745361328125
# Total loss decreased from 1.0674290020597983 to 1.041413380529557, saving weights
# Epoch 13/50
# Average number of overlapping bounding boxes from RPN = 5.02 for 50 previous iterations
# 50/50 [==============================] - 24s - rpn_cls: 0.1310 - rpn_regr: 0.1233 - detector_cls: 0.3948 - detector_regr: 0.3809
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 4.68
# Classifier accuracy for bounding boxes from RPN: 0.85375
# Loss RPN classifier: 0.13097183694466366
# Loss RPN regression: 0.1232709313929081
# Loss Detector classifier: 0.394776571393013
# Loss Detector regression: 0.38087188467383387
# Elapsed time: 25.415242433547974
# Total loss decreased from 1.041413380529557 to 1.0298912244044187, saving weights
# Epoch 14/50
# Average number of overlapping bounding boxes from RPN = 4.68 for 50 previous iterations
# 50/50 [==============================] - 26s - rpn_cls: 0.1283 - rpn_regr: 0.1226 - detector_cls: 0.4435 - detector_regr: 0.3873
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.52
# Classifier accuracy for bounding boxes from RPN: 0.828125
# Loss RPN classifier: 0.1282674551362288
# Loss RPN regression: 0.12255350939929485
# Loss Detector classifier: 0.4434756937623024
# Loss Detector regression: 0.3873489610850811
# Elapsed time: 27.09759759902954
# Epoch 15/50
# Average number of overlapping bounding boxes from RPN = 5.52 for 50 previous iterations
# 50/50 [==============================] - 24s - rpn_cls: 0.0703 - rpn_regr: 0.1125 - detector_cls: 0.4138 - detector_regr: 0.3899
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.18
# Classifier accuracy for bounding boxes from RPN: 0.838125
# Loss RPN classifier: 0.07033607906734687
# Loss RPN regression: 0.11251810125424527
# Loss Detector classifier: 0.41378837198019025
# Loss Detector regression: 0.3898842048645019
# Elapsed time: 24.966079473495483
# Total loss decreased from 1.0298912244044187 to 0.9865267571662844, saving weights
# Epoch 16/50
# Average number of overlapping bounding boxes from RPN = 5.18 for 50 previous iterations
# 50/50 [==============================] - 27s - rpn_cls: 0.1351 - rpn_regr: 0.1181 - detector_cls: 0.4006 - detector_regr: 0.3629
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.26
# Classifier accuracy for bounding boxes from RPN: 0.836875
# Loss RPN classifier: 0.13505766375612438
# Loss RPN regression: 0.11812298910692334
# Loss Detector classifier: 0.40062603682279585
# Loss Detector regression: 0.3629145433008671
# Elapsed time: 27.945361852645874
# Epoch 17/50
# Average number of overlapping bounding boxes from RPN = 5.26 for 50 previous iterations
# 50/50 [==============================] - 26s - rpn_cls: 0.1401 - rpn_regr: 0.1119 - detector_cls: 0.3840 - detector_regr: 0.3588
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.36
# Classifier accuracy for bounding boxes from RPN: 0.84
# Loss RPN classifier: 0.14006622661545406
# Loss RPN regression: 0.11186188542284072
# Loss Detector classifier: 0.3839563249051571
# Loss Detector regression: 0.35883684769272806
# Elapsed time: 26.478172540664673
# Epoch 18/50
# Average number of overlapping bounding boxes from RPN = 5.36 for 50 previous iterations
# 50/50 [==============================] - 25s - rpn_cls: 0.1833 - rpn_regr: 0.1157 - detector_cls: 0.3688 - detector_regr: 0.3624
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 4.72
# Classifier accuracy for bounding boxes from RPN: 0.854375
# Loss RPN classifier: 0.1832640068638648
# Loss RPN regression: 0.11574015275575221
# Loss Detector classifier: 0.3687744742631912
# Loss Detector regression: 0.36244978964328767
# Elapsed time: 25.079521417617798
# Epoch 19/50
# Average number of overlapping bounding boxes from RPN = 4.72 for 50 previous iterations
# 50/50 [==============================] - 26s - rpn_cls: 0.1011 - rpn_regr: 0.1007 - detector_cls: 0.3448 - detector_regr: 0.3315
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 4.9
# Classifier accuracy for bounding boxes from RPN: 0.851875
# Loss RPN classifier: 0.10107588347161255
# Loss RPN regression: 0.10068174398969859
# Loss Detector classifier: 0.3447664713859558
# Loss Detector regression: 0.3315235508978367
# Elapsed time: 26.69252896308899
# Total loss decreased from 0.9865267571662844 to 0.8780476497451036, saving weights
# Epoch 20/50
# Average number of overlapping bounding boxes from RPN = 4.9 for 50 previous iterations
# 50/50 [==============================] - 25s - rpn_cls: 0.0786 - rpn_regr: 0.1074 - detector_cls: 0.3835 - detector_regr: 0.3507
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.3
# Classifier accuracy for bounding boxes from RPN: 0.836875
# Loss RPN classifier: 0.07857228986950758
# Loss RPN regression: 0.10743932482553646
# Loss Detector classifier: 0.3834837430715561
# Loss Detector regression: 0.3506686471402645
# Elapsed time: 25.632116079330444
# Epoch 21/50
# Average number of overlapping bounding boxes from RPN = 5.3 for 50 previous iterations
# 50/50 [==============================] - 27s - rpn_cls: 0.1264 - rpn_regr: 0.1187 - detector_cls: 0.3583 - detector_regr: 0.3053
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.12
# Classifier accuracy for bounding boxes from RPN: 0.84375
# Loss RPN classifier: 0.1264163390151589
# Loss RPN regression: 0.11869768178090453
# Loss Detector classifier: 0.35830709010362627
# Loss Detector regression: 0.30531832844018936
# Elapsed time: 27.03008246421814
# Epoch 22/50
# Average number of overlapping bounding boxes from RPN = 5.12 for 50 previous iterations
# 50/50 [==============================] - 25s - rpn_cls: 0.1338 - rpn_regr: 0.1213 - detector_cls: 0.3544 - detector_regr: 0.3352
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.54
# Classifier accuracy for bounding boxes from RPN: 0.84625
# Loss RPN classifier: 0.13378639508585366
# Loss RPN regression: 0.1212987060379237
# Loss Detector classifier: 0.35436311781406404
# Loss Detector regression: 0.33523332938551903
# Elapsed time: 25.31904411315918
# Epoch 23/50
# Average number of overlapping bounding boxes from RPN = 5.54 for 50 previous iterations
# 50/50 [==============================] - 26s - rpn_cls: 0.1646 - rpn_regr: 0.0910 - detector_cls: 0.3555 - detector_regr: 0.3641
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.42
# Classifier accuracy for bounding boxes from RPN: 0.848125
# Loss RPN classifier: 0.16462777745649873
# Loss RPN regression: 0.09103923823218793
# Loss Detector classifier: 0.35552769631147385
# Loss Detector regression: 0.36408363960683343
# Elapsed time: 26.636217832565308
# Epoch 24/50
# Average number of overlapping bounding boxes from RPN = 5.42 for 50 previous iterations
# 50/50 [==============================] - 26s - rpn_cls: 0.1068 - rpn_regr: 0.1044 - detector_cls: 0.3312 - detector_regr: 0.3415
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.3
# Classifier accuracy for bounding boxes from RPN: 0.854375
# Loss RPN classifier: 0.10680902165942825
# Loss RPN regression: 0.10439352685352787
# Loss Detector classifier: 0.3312039431929588
# Loss Detector regression: 0.3414683400094509
# Elapsed time: 26.80506706237793
# Epoch 25/50
# Average number of overlapping bounding boxes from RPN = 5.3 for 50 previous iterations
# 50/50 [==============================] - 24s - rpn_cls: 0.0600 - rpn_regr: 0.0973 - detector_cls: 0.3065 - detector_regr: 0.2972
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.18
# Classifier accuracy for bounding boxes from RPN: 0.868125
# Loss RPN classifier: 0.060029755120813204
# Loss RPN regression: 0.09728742715436965
# Loss Detector classifier: 0.3065293344855309
# Loss Detector regression: 0.2971692492812872
# Elapsed time: 24.784215927124023
# Total loss decreased from 0.8780476497451036 to 0.7610157660420009, saving weights
# Epoch 26/50
# Average number of overlapping bounding boxes from RPN = 5.18 for 50 previous iterations
# 50/50 [==============================] - 25s - rpn_cls: 0.0658 - rpn_regr: 0.1064 - detector_cls: 0.3174 - detector_regr: 0.3205
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.42
# Classifier accuracy for bounding boxes from RPN: 0.859375
# Loss RPN classifier: 0.06575555492674084
# Loss RPN regression: 0.10639033154118806
# Loss Detector classifier: 0.3174488410353661
# Loss Detector regression: 0.3205461359769106
# Elapsed time: 26.261840343475342
# Epoch 27/50
# Average number of overlapping bounding boxes from RPN = 5.42 for 50 previous iterations
# 50/50 [==============================] - 23s - rpn_cls: 0.0907 - rpn_regr: 0.1132 - detector_cls: 0.2811 - detector_regr: 0.3033
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 4.62
# Classifier accuracy for bounding boxes from RPN: 0.86625
# Loss RPN classifier: 0.09073456752362802
# Loss RPN regression: 0.11324601671425626
# Loss Detector classifier: 0.2810848890244961
# Loss Detector regression: 0.30328560665249826
# Elapsed time: 23.98630928993225
# Epoch 28/50
# Average number of overlapping bounding boxes from RPN = 4.62 for 50 previous iterations
# 50/50 [==============================] - 26s - rpn_cls: 0.0785 - rpn_regr: 0.0949 - detector_cls: 0.3197 - detector_regr: 0.3144
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.54
# Classifier accuracy for bounding boxes from RPN: 0.860625
# Loss RPN classifier: 0.07851307112364793
# Loss RPN regression: 0.09489999768324196
# Loss Detector classifier: 0.31974128529429435
# Loss Detector regression: 0.314449018985033
# Elapsed time: 26.962971925735474
# Epoch 29/50
# Average number of overlapping bounding boxes from RPN = 5.54 for 50 previous iterations
# 50/50 [==============================] - 24s - rpn_cls: 0.0551 - rpn_regr: 0.0789 - detector_cls: 0.2935 - detector_regr: 0.2874
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.02
# Classifier accuracy for bounding boxes from RPN: 0.86625
# Loss RPN classifier: 0.05507364115162432
# Loss RPN regression: 0.0788805280753877
# Loss Detector classifier: 0.2934557769447565
# Loss Detector regression: 0.2874434684216976
# Elapsed time: 24.742230892181396
# Total loss decreased from 0.7610157660420009 to 0.7148534145934662, saving weights
# Epoch 30/50
# Average number of overlapping bounding boxes from RPN = 5.02 for 50 previous iterations
# 50/50 [==============================] - 27s - rpn_cls: 0.1684 - rpn_regr: 0.1125 - detector_cls: 0.3407 - detector_regr: 0.2901
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.78
# Classifier accuracy for bounding boxes from RPN: 0.854375
# Loss RPN classifier: 0.16835850956038484
# Loss RPN regression: 0.11254054374061524
# Loss Detector classifier: 0.3406511506438255
# Loss Detector regression: 0.2901336654275656
# Elapsed time: 27.802157640457153
# Epoch 31/50
# Average number of overlapping bounding boxes from RPN = 5.78 for 50 previous iterations
# 50/50 [==============================] - 26s - rpn_cls: 0.1265 - rpn_regr: 0.0932 - detector_cls: 0.3320 - detector_regr: 0.3183
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.6
# Classifier accuracy for bounding boxes from RPN: 0.856875
# Loss RPN classifier: 0.12651232324825287
# Loss RPN regression: 0.09324653515126556
# Loss Detector classifier: 0.33195533841848374
# Loss Detector regression: 0.31828939691185953
# Elapsed time: 26.556730270385742
# Epoch 32/50
# Average number of overlapping bounding boxes from RPN = 5.6 for 50 previous iterations
# 50/50 [==============================] - 25s - rpn_cls: 0.0827 - rpn_regr: 0.1048 - detector_cls: 0.2894 - detector_regr: 0.2728
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 4.78
# Classifier accuracy for bounding boxes from RPN: 0.8725
# Loss RPN classifier: 0.08274979053207943
# Loss RPN regression: 0.10484363975003362
# Loss Detector classifier: 0.2894349545240402
# Loss Detector regression: 0.272842715755105
# Elapsed time: 25.211238622665405
# Epoch 33/50
# Average number of overlapping bounding boxes from RPN = 4.78 for 50 previous iterations
# 50/50 [==============================] - 25s - rpn_cls: 0.0767 - rpn_regr: 0.1004 - detector_cls: 0.3075 - detector_regr: 0.2690
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.32
# Classifier accuracy for bounding boxes from RPN: 0.8625
# Loss RPN classifier: 0.07671123537056701
# Loss RPN regression: 0.10036444285418838
# Loss Detector classifier: 0.30754060052335264
# Loss Detector regression: 0.2689932009577751
# Elapsed time: 25.435507774353027
# Epoch 34/50
# Average number of overlapping bounding boxes from RPN = 5.32 for 50 previous iterations
# 50/50 [==============================] - 24s - rpn_cls: 0.0375 - rpn_regr: 0.0737 - detector_cls: 0.2559 - detector_regr: 0.2646
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 4.74
# Classifier accuracy for bounding boxes from RPN: 0.89125
# Loss RPN classifier: 0.037490922634485745
# Loss RPN regression: 0.07371041421080009
# Loss Detector classifier: 0.25587893947958945
# Loss Detector regression: 0.26458941251039503
# Elapsed time: 24.844364404678345
# Total loss decreased from 0.7148534145934662 to 0.6316696888352703, saving weights
# Epoch 35/50
# Average number of overlapping bounding boxes from RPN = 4.74 for 50 previous iterations
# 50/50 [==============================] - 27s - rpn_cls: 0.0899 - rpn_regr: 0.1097 - detector_cls: 0.3182 - detector_regr: 0.2834
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.66
# Classifier accuracy for bounding boxes from RPN: 0.8575
# Loss RPN classifier: 0.08991239851166029
# Loss RPN regression: 0.10971939193783328
# Loss Detector classifier: 0.3181512080132961
# Loss Detector regression: 0.2833810231089592
# Elapsed time: 27.74447751045227
# Epoch 36/50
# Average number of overlapping bounding boxes from RPN = 5.66 for 50 previous iterations
# 50/50 [==============================] - 25s - rpn_cls: 0.0776 - rpn_regr: 0.0915 - detector_cls: 0.2650 - detector_regr: 0.2677
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.04
# Classifier accuracy for bounding boxes from RPN: 0.8725
# Loss RPN classifier: 0.07762123331085605
# Loss RPN regression: 0.09152277413755655
# Loss Detector classifier: 0.2649994298815727
# Loss Detector regression: 0.26766403935849664
# Elapsed time: 25.147346019744873
# Epoch 37/50
# Average number of overlapping bounding boxes from RPN = 5.04 for 50 previous iterations
# 50/50 [==============================] - 25s - rpn_cls: 0.1011 - rpn_regr: 0.0931 - detector_cls: 0.2818 - detector_regr: 0.2832
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.36
# Classifier accuracy for bounding boxes from RPN: 0.875
# Loss RPN classifier: 0.10106859018191244
# Loss RPN regression: 0.09309131581976544
# Loss Detector classifier: 0.2817890797555447
# Loss Detector regression: 0.2831817321479321
# Elapsed time: 25.883042573928833
# Epoch 38/50
# Average number of overlapping bounding boxes from RPN = 5.36 for 50 previous iterations
# 50/50 [==============================] - 25s - rpn_cls: 0.0370 - rpn_regr: 0.0913 - detector_cls: 0.2719 - detector_regr: 0.2863
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.5
# Classifier accuracy for bounding boxes from RPN: 0.879375
# Loss RPN classifier: 0.036964653816539794
# Loss RPN regression: 0.09129308804229368
# Loss Detector classifier: 0.27185250490903856
# Loss Detector regression: 0.28632808377966285
# Elapsed time: 25.802140474319458
# Epoch 39/50
# Average number of overlapping bounding boxes from RPN = 5.5 for 50 previous iterations
# 50/50 [==============================] - 26s - rpn_cls: 0.0806 - rpn_regr: 0.0932 - detector_cls: 0.2868 - detector_regr: 0.2806
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.62
# Classifier accuracy for bounding boxes from RPN: 0.8725
# Loss RPN classifier: 0.08060366782672646
# Loss RPN regression: 0.09323706529627089
# Loss Detector classifier: 0.2867748726904392
# Loss Detector regression: 0.28057637721300127
# Elapsed time: 26.72543454170227
# Epoch 40/50
# Average number of overlapping bounding boxes from RPN = 5.62 for 50 previous iterations
# 50/50 [==============================] - 25s - rpn_cls: 0.0712 - rpn_regr: 0.0873 - detector_cls: 0.2665 - detector_regr: 0.2791
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.36
# Classifier accuracy for bounding boxes from RPN: 0.89
# Loss RPN classifier: 0.07121950061531607
# Loss RPN regression: 0.08733918069119681
# Loss Detector classifier: 0.26650248996913434
# Loss Detector regression: 0.2791480707377195
# Elapsed time: 25.411071062088013
# Epoch 41/50
# Average number of overlapping bounding boxes from RPN = 5.36 for 50 previous iterations
# 50/50 [==============================] - 24s - rpn_cls: 0.0591 - rpn_regr: 0.0824 - detector_cls: 0.2618 - detector_regr: 0.2608
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 4.9
# Classifier accuracy for bounding boxes from RPN: 0.883125
# Loss RPN classifier: 0.05911343319139632
# Loss RPN regression: 0.08244717515946831
# Loss Detector classifier: 0.2618267075717449
# Loss Detector regression: 0.26081050872802736
# Elapsed time: 24.78995633125305
# Epoch 42/50
# Average number of overlapping bounding boxes from RPN = 4.9 for 50 previous iterations
# 50/50 [==============================] - 27s - rpn_cls: 0.0543 - rpn_regr: 0.0846 - detector_cls: 0.2505 - detector_regr: 0.2718
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.44
# Classifier accuracy for bounding boxes from RPN: 0.885625
# Loss RPN classifier: 0.05430691895335258
# Loss RPN regression: 0.08458856646844652
# Loss Detector classifier: 0.25049205765128135
# Loss Detector regression: 0.27175298366695644
# Elapsed time: 27.03874444961548
# Epoch 43/50
# Average number of overlapping bounding boxes from RPN = 5.44 for 50 previous iterations
# 50/50 [==============================] - 25s - rpn_cls: 0.0329 - rpn_regr: 0.0871 - detector_cls: 0.2380 - detector_regr: 0.2664
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.06
# Classifier accuracy for bounding boxes from RPN: 0.88625
# Loss RPN classifier: 0.03290259060653625
# Loss RPN regression: 0.08712442481773905
# Loss Detector classifier: 0.2379927233606577
# Loss Detector regression: 0.26638745740056036
# Elapsed time: 25.318214893341064
# Total loss decreased from 0.6316696888352703 to 0.6244071961854933, saving weights
# Epoch 44/50
# Average number of overlapping bounding boxes from RPN = 5.06 for 50 previous iterations
# 50/50 [==============================] - 25s - rpn_cls: 0.0346 - rpn_regr: 0.0863 - detector_cls: 0.2710 - detector_regr: 0.2719
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.64
# Classifier accuracy for bounding boxes from RPN: 0.883125
# Loss RPN classifier: 0.03459859898953709
# Loss RPN regression: 0.08625027226131352
# Loss Detector classifier: 0.2709870529174805
# Loss Detector regression: 0.27185779742896554
# Elapsed time: 25.710343599319458
# Epoch 45/50
# Average number of overlapping bounding boxes from RPN = 5.64 for 50 previous iterations
# 50/50 [==============================] - 25s - rpn_cls: 0.0433 - rpn_regr: 0.0730 - detector_cls: 0.2338 - detector_regr: 0.2561
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.14
# Classifier accuracy for bounding boxes from RPN: 0.90375
# Loss RPN classifier: 0.043324353166244695
# Loss RPN regression: 0.07301447195286528
# Loss Detector classifier: 0.2338294542580843
# Loss Detector regression: 0.25612951681017876
# Elapsed time: 25.615065336227417
# Total loss decreased from 0.6244071961854933 to 0.606297796187373, saving weights
# Epoch 46/50
# Average number of overlapping bounding boxes from RPN = 5.14 for 50 previous iterations
# 50/50 [==============================] - 25s - rpn_cls: 0.0440 - rpn_regr: 0.0893 - detector_cls: 0.2315 - detector_regr: 0.2502
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.26
# Classifier accuracy for bounding boxes from RPN: 0.896875
# Loss RPN classifier: 0.04400107267197782
# Loss RPN regression: 0.08934307415096555
# Loss Detector classifier: 0.23149743154644967
# Loss Detector regression: 0.2502187920734286
# Elapsed time: 25.85236144065857
# Epoch 47/50
# Average number of overlapping bounding boxes from RPN = 5.26 for 50 previous iterations
# 50/50 [==============================] - 25s - rpn_cls: 0.0421 - rpn_regr: 0.0778 - detector_cls: 0.2341 - detector_regr: 0.2603
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.28
# Classifier accuracy for bounding boxes from RPN: 0.89625
# Loss RPN classifier: 0.042145155916036854
# Loss RPN regression: 0.07776971248909831
# Loss Detector classifier: 0.23409240305423737
# Loss Detector regression: 0.26029167994856833
# Elapsed time: 25.623936653137207
# Epoch 48/50
# Average number of overlapping bounding boxes from RPN = 5.28 for 50 previous iterations
# 50/50 [==============================] - 26s - rpn_cls: 0.0216 - rpn_regr: 0.0887 - detector_cls: 0.2118 - detector_regr: 0.2514
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.38
# Classifier accuracy for bounding boxes from RPN: 0.908125
# Loss RPN classifier: 0.021551024002442888
# Loss RPN regression: 0.08871845431393012
# Loss Detector classifier: 0.21183969527482988
# Loss Detector regression: 0.2514283713698387
# Elapsed time: 26.408685207366943
# Total loss decreased from 0.606297796187373 to 0.5735375449610416, saving weights
# Epoch 49/50
# Average number of overlapping bounding boxes from RPN = 5.38 for 50 previous iterations
# 50/50 [==============================] - 25s - rpn_cls: 0.0352 - rpn_regr: 0.0727 - detector_cls: 0.2492 - detector_regr: 0.2529
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.32
# Classifier accuracy for bounding boxes from RPN: 0.883125
# Loss RPN classifier: 0.03517294077683346
# Loss RPN regression: 0.07269130662636598
# Loss Detector classifier: 0.249203409999609
# Loss Detector regression: 0.2528638514131308
# Elapsed time: 26.15152931213379
# Epoch 50/50
# Average number of overlapping bounding boxes from RPN = 5.32 for 50 previous iterations
# 50/50 [==============================] - 25s - rpn_cls: 0.0564 - rpn_regr: 0.0730 - detector_cls: 0.2453 - detector_regr: 0.2749
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 5.28
# Classifier accuracy for bounding boxes from RPN: 0.8975
# Loss RPN classifier: 0.05638371592164731
# Loss RPN regression: 0.07302163746935549
# Loss Detector classifier: 0.24533521480858325
# Loss Detector regression: 0.2749155561625958
# Elapsed time: 25.83933734893799
# Training complete, exiting.

# %%
# !python test_frcnn.py -p test_images
# Out:
# Using TensorFlow backend.
# {0: 'Pedastrian', 1: 'bg'}
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:47: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:351: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3176: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3043: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3153: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /content/original/keras_frcnn/RoiPoolingConv.py:105: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3045: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1064: calling reduce_prod_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# Loading weights from ./model_frcnn.hdf5
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:141: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:146: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:151: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-07-12 09:15:23.525159: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-07-12 09:15:23.525457: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0xb4e21c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-07-12 09:15:23.525489: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-07-12 09:15:23.527579: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-07-12 09:15:23.636865: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-12 09:15:23.637760: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0xb4e2380 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-07-12 09:15:23.637794: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-07-12 09:15:23.638061: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-12 09:15:23.638787: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-07-12 09:15:23.639213: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-07-12 09:15:23.641177: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-07-12 09:15:23.642956: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-07-12 09:15:23.643386: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-07-12 09:15:23.645049: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-07-12 09:15:23.645767: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-07-12 09:15:23.649248: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-07-12 09:15:23.649388: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-12 09:15:23.650214: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-12 09:15:23.651191: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-07-12 09:15:23.651288: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-07-12 09:15:23.652916: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-07-12 09:15:23.652945: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-07-12 09:15:23.652960: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-07-12 09:15:23.653131: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-12 09:15:23.653926: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-12 09:15:23.654843: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-07-12 09:15:23.654890: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:300: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:308: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:675: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# PennPed00027.png
# 2020-07-12 09:15:26.175252: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-07-12 09:15:27.254640: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# Elapsed time = 3.181929349899292
# [('Pedastrian', 95.80795168876648)]
# PennPed00028.png
# Elapsed time = 0.6554937362670898
# [('Pedastrian', 91.4030373096466), ('Pedastrian', 91.08736515045166)]
# PennPed00029.png
# Elapsed time = 0.7717111110687256
# [('Pedastrian', 96.61336541175842), ('Pedastrian', 93.36823225021362), ('Pedastrian', 90.63305854797363)]
# PennPed00030.png
# Elapsed time = 0.7016634941101074
# [('Pedastrian', 98.62812161445618), ('Pedastrian', 96.10154628753662), ('Pedastrian', 85.60765981674194), ('Pedastrian', 81.65320754051208)]
# PennPed00031.png
# Elapsed time = 0.7537288665771484
# [('Pedastrian', 90.51330089569092), ('Pedastrian', 86.43901944160461), ('Pedastrian', 85.49526333808899)]
# PennPed00032.png
# Elapsed time = 0.6214644908905029
# []
# PennPed00033.png
# Elapsed time = 0.6194682121276855
# [('Pedastrian', 86.87744140625), ('Pedastrian', 85.87719202041626), ('Pedastrian', 85.14435887336731), ('Pedastrian', 81.24915361404419), ('Pedastrian', 80.05412817001343)]
# PennPed00034.png
# Elapsed time = 0.7021152973175049
# [('Pedastrian', 95.4617440700531), ('Pedastrian', 84.88117456436157)]
# PennPed00035.png
# Elapsed time = 0.7557730674743652
# [('Pedastrian', 90.70050120353699), ('Pedastrian', 87.25192546844482), ('Pedastrian', 82.84228444099426)]
# PennPed00036.png
# Elapsed time = 0.8028378486633301
# [('Pedastrian', 90.58470129966736)]
# PennPed00037.png
# Elapsed time = 0.5343410968780518
# [('Pedastrian', 83.99575352668762)]
# PennPed00038.png
# Elapsed time = 0.5410470962524414
# [('Pedastrian', 85.48945784568787)]
# PennPed00039.png
# Elapsed time = 0.6572716236114502
# []
# PennPed00040.png
# Elapsed time = 0.6683051586151123
# [('Pedastrian', 83.71642827987671)]
# PennPed00041.png
# Elapsed time = 0.5107095241546631
# []
# PennPed00042.png
# Elapsed time = 0.8002326488494873
# [('Pedastrian', 92.90252923965454), ('Pedastrian', 86.17387413978577), ('Pedastrian', 86.09305024147034), ('Pedastrian', 83.67185592651367), ('Pedastrian', 82.451730966568)]
# PennPed00043.png
# Elapsed time = 0.6102683544158936
# [('Pedastrian', 85.88364720344543), ('Pedastrian', 82.85775780677795), ('Pedastrian', 81.96986317634583)]
# PennPed00044.png
# Elapsed time = 0.6222395896911621
# [('Pedastrian', 80.57296872138977)]
# PennPed00045.png
# Elapsed time = 0.664851188659668
# [('Pedastrian', 88.8939917087555), ('Pedastrian', 87.03283667564392), ('Pedastrian', 82.245934009552), ('Pedastrian', 81.45710825920105)]
# PennPed00046.png
# Elapsed time = 0.7314763069152832
# []
# PennPed00047.png
# Elapsed time = 0.5959568023681641
# [('Pedastrian', 95.10347843170166), ('Pedastrian', 87.31710910797119), ('Pedastrian', 86.12438440322876), ('Pedastrian', 85.79626679420471), ('Pedastrian', 82.58109092712402)]
# PennPed00048.png
# Elapsed time = 0.6534943580627441
# [('Pedastrian', 89.98982906341553), ('Pedastrian', 87.8934383392334), ('Pedastrian', 86.31166219711304)]
# PennPed00049.png
# Elapsed time = 0.7073965072631836
# [('Pedastrian', 86.93524599075317), ('Pedastrian', 84.03586745262146)]
# PennPed00050.png
# Elapsed time = 0.5974082946777344
# [('Pedastrian', 90.00282287597656)]
# PennPed00051.png
# Elapsed time = 0.649259090423584
# [('Pedastrian', 88.78108859062195), ('Pedastrian', 87.77419328689575), ('Pedastrian', 86.80554032325745), ('Pedastrian', 83.49090814590454), ('Pedastrian', 81.24078512191772)]
# PennPed00052.png
# Elapsed time = 0.5692920684814453
# [('Pedastrian', 93.99675726890564), ('Pedastrian', 82.6660692691803), ('Pedastrian', 80.2103042602539)]
# PennPed00053.png
# Elapsed time = 0.5763757228851318
# [('Pedastrian', 93.98004412651062), ('Pedastrian', 93.42665076255798), ('Pedastrian', 84.75452661514282)]
# PennPed00054.png
# Elapsed time = 0.5928769111633301
# []
# PennPed00055.png
# Elapsed time = 0.6263232231140137
# [('Pedastrian', 81.78938627243042)]
# PennPed00056.png
# Elapsed time = 0.7484104633331299
# []
# PennPed00057.png
# Elapsed time = 0.632286787033081
# [('Pedastrian', 82.0438802242279), ('Pedastrian', 81.64560198783875)]
# PennPed00058.png
# Elapsed time = 0.6042022705078125
# []
# PennPed00059.png
# Elapsed time = 0.5899932384490967
# [('Pedastrian', 88.4289801120758)]
# PennPed00060.png
# Elapsed time = 0.5925016403198242
# [('Pedastrian', 81.86255097389221), ('Pedastrian', 80.91447949409485)]
# PennPed00061.png
# Elapsed time = 0.5060708522796631
# [('Pedastrian', 96.65916562080383), ('Pedastrian', 94.29227113723755)]
# PennPed00062.png
# Elapsed time = 0.5103802680969238
# [('Pedastrian', 91.4629340171814), ('Pedastrian', 89.27307724952698), ('Pedastrian', 88.85722160339355), ('Pedastrian', 87.6251757144928), ('Pedastrian', 82.70835280418396)]
# PennPed00063.png
# Elapsed time = 0.6299128532409668
# []
# PennPed00064.png
# Elapsed time = 0.4482996463775635
# []
# PennPed00065.png
# Elapsed time = 0.39356303215026855
# []
# PennPed00066.png
# Elapsed time = 0.514305830001831
# [('Pedastrian', 91.41069650650024)]
# PennPed00067.png
# Elapsed time = 0.544752836227417
# [('Pedastrian', 83.48746299743652)]
# PennPed00068.png
# Elapsed time = 0.7943387031555176
# []
# PennPed00069.png
# Elapsed time = 0.5988903045654297
# [('Pedastrian', 96.91592454910278), ('Pedastrian', 94.9462890625), ('Pedastrian', 92.50600337982178), ('Pedastrian', 86.51995658874512), ('Pedastrian', 82.55271911621094), ('Pedastrian', 80.02692461013794)]
# PennPed00070.png
# Elapsed time = 0.5791282653808594
# [('Pedastrian', 96.51915431022644), ('Pedastrian', 82.381272315979)]
# PennPed00071.png
# Elapsed time = 0.8486459255218506
# [('Pedastrian', 93.5211718082428), ('Pedastrian', 89.06113505363464), ('Pedastrian', 82.95612335205078)]
# PennPed00072.png
# Elapsed time = 0.6006691455841064
# [('Pedastrian', 91.76588654518127), ('Pedastrian', 90.81963300704956), ('Pedastrian', 83.85123014450073)]
# PennPed00073.png
# Elapsed time = 0.653684139251709
# []
# PennPed00074.png
# Elapsed time = 0.5342164039611816
# [('Pedastrian', 91.92839860916138), ('Pedastrian', 86.63562536239624), ('Pedastrian', 81.53632283210754)]
# PennPed00075.png
# Elapsed time = 0.5635433197021484
# [('Pedastrian', 96.18454575538635), ('Pedastrian', 94.23584342002869), ('Pedastrian', 82.18496441841125)]
# PennPed00076.png
# Elapsed time = 0.42204761505126953
# [('Pedastrian', 83.72118473052979)]
# PennPed00077.png
# Elapsed time = 0.4719395637512207
# []
# PennPed00078.png
# Elapsed time = 0.5821859836578369
# []
# PennPed00079.png
# Elapsed time = 0.6113495826721191
# [('Pedastrian', 95.32345533370972)]
# PennPed00080.png
# Elapsed time = 0.6102514266967773
# [('Pedastrian', 97.44964838027954), ('Pedastrian', 95.80879211425781), ('Pedastrian', 95.27227878570557), ('Pedastrian', 92.10403561592102), ('Pedastrian', 91.34130477905273), ('Pedastrian', 83.3383560180664), ('Pedastrian', 82.78314471244812)]
# PennPed00081.png
# Elapsed time = 0.6861231327056885
# [('Pedastrian', 97.30269312858582), ('Pedastrian', 96.58221006393433), ('Pedastrian', 94.68232989311218), ('Pedastrian', 89.31825757026672), ('Pedastrian', 89.13758397102356), ('Pedastrian', 88.1152331829071), ('Pedastrian', 87.13489770889282), ('Pedastrian', 86.62712574005127), ('Pedastrian', 85.82339882850647), ('Pedastrian', 85.47337055206299), ('Pedastrian', 84.847891330719)]
# PennPed00082.png
# Elapsed time = 0.49022459983825684
# [('Pedastrian', 87.19426393508911)]
# PennPed00083.png
# Elapsed time = 0.4624028205871582
# []
# PennPed00084.png
# Elapsed time = 0.6482245922088623
# [('Pedastrian', 84.39491391181946)]
# PennPed00085.png
# Elapsed time = 0.448380708694458
# []
# PennPed00086.png
# Elapsed time = 0.5049736499786377
# [('Pedastrian', 93.59015226364136), ('Pedastrian', 92.53115653991699), ('Pedastrian', 85.38626432418823), ('Pedastrian', 85.25624871253967), ('Pedastrian', 81.97701573371887), ('Pedastrian', 81.63732886314392)]
# PennPed00087.png
# Elapsed time = 0.6019153594970703
# [('Pedastrian', 88.1335973739624), ('Pedastrian', 87.44359016418457), ('Pedastrian', 81.3692569732666)]
# PennPed00088.png
# Elapsed time = 0.5178847312927246
# [('Pedastrian', 94.68352198600769)]
# PennPed00089.png
# Elapsed time = 0.4614236354827881
# [('Pedastrian', 85.02925634384155)]
# PennPed00090.png
# Elapsed time = 0.4919426441192627
# [('Pedastrian', 94.09593939781189), ('Pedastrian', 87.90897727012634), ('Pedastrian', 86.42430901527405), ('Pedastrian', 81.3680648803711)]
# PennPed00091.png
# Elapsed time = 0.5215420722961426
# [('Pedastrian', 86.60023808479309), ('Pedastrian', 84.241783618927), ('Pedastrian', 83.92711877822876), ('Pedastrian', 83.89624953269958)]
# PennPed00092.png
# Elapsed time = 0.5546085834503174
# [('Pedastrian', 94.66632008552551), ('Pedastrian', 93.25786232948303), ('Pedastrian', 83.31781029701233), ('Pedastrian', 82.831871509552)]
# PennPed00093.png
# Elapsed time = 0.4416923522949219
# [('Pedastrian', 98.13709855079651), ('Pedastrian', 93.05028915405273), ('Pedastrian', 90.55616855621338), ('Pedastrian', 82.0943534374237)]
# PennPed00094.png
# Elapsed time = 0.5500361919403076
# [('Pedastrian', 81.98250532150269)]
# PennPed00095.png
# Elapsed time = 0.531139612197876
# [('Pedastrian', 90.94468951225281)]
# PennPed00096.png
# Elapsed time = 0.6476421356201172
# []

# %%
coordinates = pd.read_csv('coordinates.csv')
