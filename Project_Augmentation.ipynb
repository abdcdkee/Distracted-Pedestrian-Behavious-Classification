# %%
from google.colab import drive
drive.mount('/content/gdrive')

# !pip install -q git+https://github.com/tensorflow/docs


import urllib

import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras import layers
AUTOTUNE = tf.data.experimental.AUTOTUNE

import tensorflow_docs as tfdocs
import tensorflow_docs.plots

import tensorflow_datasets as tfds

import PIL.Image

import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = (12, 5)

import numpy as np

# %% [markdown]
# #Augmenting data

# %%
#The function helps visualize the original and augmented image.
def visualize(original, augmented):
  fig = plt.figure()
  plt.subplot(1,2,1)
  plt.title('Original image')
  plt.imshow(original)

  plt.subplot(1,2,2)
  plt.title('Augmented image')
  plt.imshow(augmented)


#The code below helps augment the sorted data into as many augmentations as needed by commenting/uncommenting the lines saving images to drive.
data = []
import os

download_path = '/content/gdrive/My Drive/SortedTrainData/Alert/'
upload_path = '/content/gdrive/My Drive/AugmentedDataRandom3 /Alert/'
counter = 1
for filename in os.listdir(download_path):
      image_path = download_path + '/' + filename
    
      if image_path.endswith(".bmp") == False:

        image_path = download_path + '/' + filename
        image_string=tf.io.read_file(image_path)
        #print(image_path)
        image=tf.image.decode_png(image_string,channels=3)
        tf.keras.preprocessing.image.save_img(upload_path + str(counter)+'.jpg', image)

        flipped = tf.image.flip_left_right(image)
        #visualize(image, flipped)
        tf.keras.preprocessing.image.save_img(upload_path +str(counter+1)+'.jpg', flipped)
      
        grayscaled = tf.image.rgb_to_grayscale(image)
        grayscaled2 = tf.image.rgb_to_grayscale(flipped)

        #tf.keras.preprocessing.image.save_img(upload_path +str(counter+2)+'.jpg', grayscaled)
        #tf.keras.preprocessing.image.save_img(upload_path +str(counter+3)+'.jpg', grayscaled2)


        saturated = tf.image.adjust_saturation(image, 2)
        saturated2 = tf.image.adjust_saturation(flipped, 2)
        saturated3 = tf.image.adjust_saturation(image, 3)
        saturated4 = tf.image.adjust_saturation(flipped, 3)
        saturated5 = tf.image.adjust_saturation(image, 6)
        saturated6 = tf.image.adjust_saturation(flipped, 6)

        #visualize(image, saturated)
        #visualize(flipped, saturated2)
        #visualize(image, saturated3)
        #visualize(flipped, saturated4)
        #visualize(image, saturated5)
        #visualize(flipped, saturated6)
        #tf.keras.preprocessing.image.save_img(upload_path +str(counter+4)+'.jpg', saturated)
        #tf.keras.preprocessing.image.save_img(upload_path +str(counter+5)+'.jpg', saturated2)
        #tf.keras.preprocessing.image.save_img(upload_path +str(counter+2)+'.jpg', saturated3)
        #tf.keras.preprocessing.image.save_img(upload_path +str(counter+3)+'.jpg', saturated4)
        #tf.keras.preprocessing.image.save_img(upload_path +str(counter+8)+'.jpg', saturated5)
        #tf.keras.preprocessing.image.save_img(upload_path +str(counter+9)+'.jpg', saturated6)


        bright = tf.image.adjust_brightness(image, 0.2)
        bright2 = tf.image.adjust_brightness(flipped, 0.2)
        bright3 = tf.image.adjust_brightness(image, 0.3)
        bright4 = tf.image.adjust_brightness(flipped, 0.3)
        bright5 = tf.image.adjust_brightness(image, 0.4)
        bright6 = tf.image.adjust_brightness(flipped, 0.4)

        #visualize(image, bright)
        #visualize(flipped, bright2)
        #visualize(image, bright3)
        #visualize(flipped, bright4)
        #visualize(image, bright5)
        #visualize(flipped, bright6)
        #tf.keras.preprocessing.image.save_img(upload_path +str(counter+8)+'.jpg', bright)
        #tf.keras.preprocessing.image.save_img(upload_path +str(counter+9)+'.jpg', bright2)
        #tf.keras.preprocessing.image.save_img(upload_path +str(counter+6)+'.jpg', bright3)
        #tf.keras.preprocessing.image.save_img(upload_path +str(counter+7)+'.jpg', bright4)
        #tf.keras.preprocessing.image.save_img(upload_path +str(counter+3)+'.jpg', bright5)
        #tf.keras.preprocessing.image.save_img(upload_path +str(counter+15)+'.jpg', bright6)


        #rotated = tf.image.rot90(image)
        #visualize(image, rotated)
        #tf.keras.preprocessing.image.save_img(upload_path +str(counter+5)+'.jpg', rotated)

        #cropped = tf.image.central_crop(image, central_fraction=0.5)
        #visualize(image,cropped)
        #tf.keras.preprocessing.image.save_img(upload_path +str(counter+6)+'.jpg', cropped)

      counter+=2 ##Change if u uncomment something bruv
      print(counter)
      if image_path.endswith(".bmp"):
        print("Image Ignored")
        counter-=2
